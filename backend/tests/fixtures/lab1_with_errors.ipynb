# %% [markdown]
# # Lab 1 — Student with errors
#
# This notebook has a runtime error in one cell.

# %%
import numpy as np
X = np.array([1, 2, 3])
print('Loaded data')
# Out:
# Loaded data

# %%
# Bug: wrong variable name causes NameError
y_pred = w * X + b
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Bug: wrong variable name causes NameError
# --- > 2 y_pred = w * X + b
# NameError: name 'w' is not defined

# %%
# This cell never ran because of the error above
print('This should have been the final evaluation')
