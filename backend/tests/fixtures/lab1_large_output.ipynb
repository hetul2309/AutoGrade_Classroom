# %% [markdown]
# # Lab with large output
#
# Tests that extremely long outputs are truncated properly.

# %%
# Print a very large output that should be truncated
for i in range(500):
    print(f'Epoch {i}: loss={1.0/(i+1):.6f}')
# Out:
# Epoch 0: loss=1.000000
# Epoch 1: loss=0.500000
# Epoch 2: loss=0.333333
# Epoch 3: loss=0.250000
# Epoch 4: loss=0.200000
# Epoch 5: loss=0.166667
# Epoch 6: loss=0.142857
# Epoch 7: loss=0.125000
# Epoch 8: loss=0.111111
# Epoch 9: loss=0.100000
# Epoch 10: loss=0.090909
# Epoch 11: loss=0.083333
# Epoch 12: loss=0.076923
# Epoch 13: loss=0.071429
# Epoch 14: loss=0.066667
# Epoch 15: loss=0.062500
# Epoch 16: loss=0.058824
# Epoch 17: loss=0.055556
# Epoch 18: loss=0.052632
# Epoch 19: loss=0.050000
# Epoch 20: loss=0.047619
# ... (9000 more lines omitted in this fixture)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Multiple plots — all binary, should all be replaced by placeholder
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot([1,2,3], [4,5,6])
axes[1].scatter([1,2,3], [4,5,6])
plt.show()

# %%
# Normal short output after the big ones
print('Final accuracy: 0.923')
# Out:
# Final accuracy: 0.923
